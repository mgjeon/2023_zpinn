# %%
import os

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]= "3"

# %%
import numpy as np

# %%
b_bottom_path = '/userhome/jeon_mg/workspace/project/CNN_NF2/NF2_compare/data/inputs_12673.npy'
Nz = 50
b_norm = 2500

# %%
b = np.load(b_bottom_path)*b_norm
b_bottom = b.squeeze().transpose(1, 2, 0)
b_bottom.shape
# Out:
# (513, 257, 3)

# %%
output_path = os.path.join('output')
os.makedirs(output_path, exist_ok=True)

# %%
import matplotlib.pyplot as plt

# %%
plt.close()
fig, ax = plt.subplots(figsize=(6,6))
CS = plt.imshow(b_bottom[:, :, 2].transpose(), origin='lower', cmap='gray')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title("B_z(z=0)")
fig.colorbar(CS)
plt.show()

# %%
from cmspinn.potential_field import cal_and_save_potential_boundary_for_spinn

# %%
boundary_path = os.path.join(output_path, 'boundary.pickle')

# %%
cal_and_save_potential_boundary_for_spinn(b_bottom, Nz, b_norm, boundary_path, reduce=1)
# Out:
# Potential Boundary: 100%|██████████| 306/306 [00:18<00:00, 16.51it/s]
