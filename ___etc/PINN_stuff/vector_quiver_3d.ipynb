# %%
import numpy as np

x, y, z = np.meshgrid(np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.8))

u = np.sin(np.pi * x) * np.cos(np.pi * y) * np.cos(np.pi * z)
v = -np.cos(np.pi * x) * np.sin(np.pi * y) * np.cos(np.pi * z)
w = (np.sqrt(2.0 / 3.0) * np.cos(np.pi * x) * np.cos(np.pi * y) *
     np.sin(np.pi * z))

points = np.vstack((x.ravel(), y.ravel(), z.ravel())).T 
vectors = np.vstack((u.ravel(), v.ravel(), w.ravel())).T

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.quiver(x, y, z, u, v, w, length=0.1, normalize=True)
plt.show()

# %%
import pyvista as pv
pdata = pv.vector_poly_data(points, vectors)
mesh = pdata.glyph(orient='vectors', scale='mag')

# %%
p = pv.Plotter()
p.add_mesh(mesh)
p.show()
# Out:
# Widget(value="<iframe src='http://localhost:42669/index.html?ui=P_0x7f3b29d96290_0&reconnect=auto' style='widt…

# %%
import k3d
plot = k3d.plot()
plot += k3d.vtk_poly_data(mesh)
plot.display()
# Out:
# Output()
