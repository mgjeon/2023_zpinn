# %% [markdown]
# # HMI input

# %%
import os
import drms
from datetime import datetime, timedelta

# %%
jsoc_email = 'mgjeon@khu.ac.kr'
client = drms.Client(email=jsoc_email, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 jsoc_email = 'mgjeon@khu.ac.kr'
# ----> 2 client = drms.Client(email=jsoc_email, verbose=True)
#
# File ~/mambaforge/envs/pinf/lib/python3.10/site-packages/drms/client.py:629, in Client.__init__(self, server, email, verbose, debug)
#     627 self._info_cache = {}
#     628 self.verbose = verbose  # use property for convertion to bool
# --> 629 self.email = email
#
# File ~/mambaforge/envs/pinf/lib/python3.10/site-packages/drms/client.py:849, in Client.email(self, value)
#     847 @email.setter
#     848 def email(self, value):
# --> 849     if value is not None and not self.check_email(value):
#     850         raise ValueError("Email address is invalid or not registered")
#     851     self._email = value
#
# File ~/mambaforge/envs/pinf/lib/python3.10/site-packages/drms/client.py:1126, in Client.check_email(self, email)
#    1124 if not self._server.check_supported("email"):
#    1125     raise DrmsOperationNotSupported("Server does not support user emails")
# -> 1126 res = self._json.check_address(email)
#    1127 status = res.get("status")
#    1128 return status is not None and int(status) == 2
#
# File ~/mambaforge/envs/pinf/lib/python3.10/site-packages/drms/json.py:288, in HttpJsonClient.check_address(self, email)
#     269 """
#     270 Check if an email address is registered for export data requests.
#     271
#    (...)
#     285     - -2: Not a valid email address
#     286 """
#     287 query = "?" + urlencode({"address": quote_plus(email), "checkonly": "1"})
# --> 288 req = self._json_request(self._server.url_check_address + query)
#     289 return req.data
#
# File ~/mambaforge/envs/pinf/lib/python3.10/site-packages/drms/json.py:120, in HttpJsonClient._json_request(self, url)
#     118 if self.debug:
#     119     print(url)
# --> 120 return HttpJsonRequest(url, self._server.encoding)
#
# File ~/mambaforge/envs/pinf/lib/python3.10/site-packages/drms/json.py:67, in HttpJsonRequest.__init__(self, url, encoding)
#      65 self._encoding = encoding
#      66 try:
# ---> 67     self._http = urlopen(url)
#      68 except HTTPError as e:
#      69     e.msg = f"Failed to open URL: {e.url} with {e.code} - {e.msg}"
#
# File ~/mambaforge/envs/pinf/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/mambaforge/envs/pinf/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~/mambaforge/envs/pinf/lib/python3.10/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~/mambaforge/envs/pinf/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/mambaforge/envs/pinf/lib/python3.10/urllib/request.py:1377, in HTTPHandler.http_open(self, req)
#    1376 def http_open(self, req):
# -> 1377     return self.do_open(http.client.HTTPConnection, req)
#
# File ~/mambaforge/envs/pinf/lib/python3.10/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346 try:
#    1347     try:
# -> 1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
#
# File ~/mambaforge/envs/pinf/lib/python3.10/http/client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1280 def request(self, method, url, body=None, headers={}, *,
#    1281             encode_chunked=False):
#    1282     """Send a complete request to the server."""
# -> 1283     self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/mambaforge/envs/pinf/lib/python3.10/http/client.py:1329, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1325 if isinstance(body, str):
#    1326     # RFC 2616 Section 3.7.1 says that text default has a
#    1327     # default charset of iso-8859-1.
#    1328     body = _encode(body, 'body')
# -> 1329 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/mambaforge/envs/pinf/lib/python3.10/http/client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276 else:
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/mambaforge/envs/pinf/lib/python3.10/http/client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 msg = b"\r\n".join(self._buffer)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#    1043     if hasattr(message_body, 'read'):
#    1044         # Let file-like take precedence over byte-like.  This
#    1045         # is needed to allow the current position of mmap'ed
#    1046         # files to be taken into account.
#
# File ~/mambaforge/envs/pinf/lib/python3.10/http/client.py:976, in HTTPConnection.send(self, data)
#     974 if self.sock is None:
#     975     if self.auto_open:
# --> 976         self.connect()
#     977     else:
#     978         raise NotConnected()
#
# File ~/mambaforge/envs/pinf/lib/python3.10/http/client.py:942, in HTTPConnection.connect(self)
#     940 """Connect to the host and port specified in __init__."""
#     941 sys.audit("http.client.connect", self, self.host, self.port)
# --> 942 self.sock = self._create_connection(
#     943     (self.host,self.port), self.timeout, self.source_address)
#     944 # Might fail in OSs that don't implement TCP_NODELAY
#     945 try:
#
# File ~/mambaforge/envs/pinf/lib/python3.10/socket.py:833, in create_connection(address, timeout, source_address)
#     831 if source_address:
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
#     834 # Break explicitly a reference cycle
#     835 err = None
#
# KeyboardInterrupt:

# %%
year = 2011
month = 2
day = 14
hour = 19
minute = 55

start_time = datetime(year, month, day, hour, minute)
start_time
